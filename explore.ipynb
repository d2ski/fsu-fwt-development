# %%
import pandas as pd
import numpy as np
from pandas_datareader import wb
import pycountry

import altair as alt

import json

import wbgapi as wb

# %% [markdown]
# ### WORLD BANK GDP PER CAPITA (PPP)

# %% [markdown]
# #### COUNTRIES

# %%
# Former USSR countries
fsu_countries = [
    {'name': 'Russia', 'region': 'Eastern Europe', 'independence': '12.12.1991'},
    {'name': 'Ukraine', 'region': 'Eastern Europe', 'independence': '24.08.1991'},
    {'name': 'Belarus', 'region': 'Eastern Europe', 'independence': '25.08.1991'},
    {'name': 'Lithuania', 'region': 'Baltic states', 'independence': '11.03.1990'},
    {'name': 'Latvia', 'region': 'Baltic states', 'independence': '4.05.1990'},
    {'name': 'Estonia', 'region': 'Baltic states', 'independence': '8.05.1990'},
    {'name': 'Moldova', 'region': 'Eastern Europe', 'independence': '27.08.1991'},
    
    {'name': 'Uzbekistan', 'region': 'Central Asia', 'independence': '31.08.1991'},
    {'name': 'Kazakhstan', 'region': 'Central Asia', 'independence': '16.12.1991'},
    {'name': 'Kyrgyzstan', 'region': 'Central Asia', 'independence': '31.08.1991'},
    {'name': 'Tajikistan', 'region': 'Central Asia', 'independence': '9.09.1991'},
    {'name': 'Turkmenistan', 'region': 'Central Asia', 'independence': '27.10.1991'},
    
    {'name': 'Georgia', 'region': 'South Caucasus', 'independence': '9.04.1991'},
    {'name': 'Azerbaijan', 'region': 'South Caucasus', 'independence': '30.08.1991'},
    {'name': 'Armenia', 'region': 'South Caucasus', 'independence': '23.08.1990'},
]

# %%
# Former Warsaw Treaty/Pact countries, excluding East Germany
fwt_countries = [
    {'name': 'Bulgaria', 'region': 'Eastern Europe', 'independence': '15.11.1990'},
    {'name': 'Slovakia', 'region': 'Eastern Europe', 'independence': '1.01.1993'},
    {'name': 'Czech Republic', 'region': 'Eastern Europe', 'independence': '1.01.1993'},
    {'name': 'Hungary', 'region': 'Eastern Europe', 'independence': '23.10.1989'},
    {'name': 'Poland', 'region': 'Eastern Europe', 'independence': '29.12.1989'},
    {'name': 'Romania', 'region': 'Eastern Europe', 'independence': '25.12.1989'},
]

# %%
# Add ISO 3 codes
for rec in fsu_countries:
    rec['iso'] = pycountry.countries.search_fuzzy(
        rec['name']
    )[0].alpha_3
    
    rec['group'] = 'FSU'
    
for rec in fwt_countries:
    rec['iso'] = pycountry.countries.search_fuzzy(
        rec['name']
    )[0].alpha_3
    
    rec['group'] = 'FWT'

# %%
iso_codes = { rec['iso']:rec for rec in fsu_countries + fwt_countries}

# %%
iso_codes
# Out:
# {'RUS': {'name': 'Russia',
#   'region': 'Eastern Europe',
#   'independence': '12.12.1991',
#   'iso': 'RUS',
#   'group': 'FSU'},
#  'UKR': {'name': 'Ukraine',
#   'region': 'Eastern Europe',
#   'independence': '24.08.1991',
#   'iso': 'UKR',
#   'group': 'FSU'},
#  'BLR': {'name': 'Belarus',
#   'region': 'Eastern Europe',
#   'independence': '25.08.1991',
#   'iso': 'BLR',
#   'group': 'FSU'},
#  'LTU': {'name': 'Lithuania',
#   'region': 'Baltic states',
#   'independence': '11.03.1990',
#   'iso': 'LTU',
#   'group': 'FSU'},
#  'LVA': {'name': 'Latvia',
#   'region': 'Baltic states',
#   'independence': '4.05.1990',
#   'iso': 'LVA',
#   'group': 'FSU'},
#  'EST': {'name': 'Estonia',
#   'region': 'Baltic states',
#   'independence': '8.05.1990',
#   'iso': 'EST',
#   'group': 'FSU'},
#  'MDA': {'name': 'Moldova',
#   'region': 'Eastern Europe',
#   'independence': '27.08.1991',
#   'iso': 'MDA',
#   'group': 'FSU'},
#  'UZB': {'name': 'Uzbekistan',
#   'region': 'Central Asia',
#   'independence': '31.08.1991',
#   'iso': 'UZB',
#   'group': 'FSU'},
#  'KAZ': {'name': 'Kazakhstan',
#   'region': 'Central Asia',
#   'independence': '16.12.1991',
#   'iso': 'KAZ',
#   'group': 'FSU'},
#  'KGZ': {'name': 'Kyrgyzstan',
#   'region': 'Central Asia',
#   'independence': '31.08.1991',
#   'iso': 'KGZ',
#   'group': 'FSU'},
#  'TJK': {'name': 'Tajikistan',
#   'region': 'Central Asia',
#   'independence': '9.09.1991',
#   'iso': 'TJK',
#   'group': 'FSU'},
#  'TKM': {'name': 'Turkmenistan',
#   'region': 'Central Asia',
#   'independence': '27.10.1991',
#   'iso': 'TKM',
#   'group': 'FSU'},
#  'GEO': {'name': 'Georgia',
#   'region': 'South Caucasus',
#   'independence': '9.04.1991',
#   'iso': 'GEO',
#   'group': 'FSU'},
#  'AZE': {'name': 'Azerbaijan',
#   'region': 'South Caucasus',
#   'independence': '30.08.1991',
#   'iso': 'AZE',
#   'group': 'FSU'},
#  'ARM': {'name': 'Armenia',
#   'region': 'South Caucasus',
#   'independence': '23.08.1990',
#   'iso': 'ARM',
#   'group': 'FSU'},
#  'BGR': {'name': 'Bulgaria',
#   'region': 'Eastern Europe',
#   'independence': '15.11.1990',
#   'iso': 'BGR',
#   'group': 'FWT'},
#  'SVK': {'name': 'Slovakia',
#   'region': 'Eastern Europe',
#   'independence': '1.01.1993',
#   'iso': 'SVK',
#   'group': 'FWT'},
#  'CZE': {'name': 'Czech Republic',
#   'region': 'Eastern Europe',
#   'independence': '1.01.1993',
#   'iso': 'CZE',
#   'group': 'FWT'},
#  'HUN': {'name': 'Hungary',
#   'region': 'Eastern Europe',
#   'independence': '23.10.1989',
#   'iso': 'HUN',
#   'group': 'FWT'},
#  'POL': {'name': 'Poland',
#   'region': 'Eastern Europe',
#   'independence': '29.12.1989',
#   'iso': 'POL',
#   'group': 'FWT'},
#  'ROU': {'name': 'Romania',
#   'region': 'Eastern Europe',
#   'independence': '25.12.1989',
#   'iso': 'ROU',
#   'group': 'FWT'}}

# %%
neighbours = [
    {"name":"Norway","id":"425"},
    {"name":"Finland","id":"434"},
    {"name":"Sweden","id":"455"},
    {"name":"Germany","id":"439"},
    {"name":"Austria","id":"317"},
    {"name":"Slovenia","id":"246"},
    {"name":"Croatia","id":"296"},
    {"name":"Bosnia and Herzegovina","id":"293"},
    {"name":"Serbia and Montenegro","id":"332"},
    #{"name":"Serbia and Montenegro","id":"353"},
    {"name":"North Macedonia","id":"256"},
    {"name":"Greece","id":"358"},
    {"name":"Turkey","id":"493"},
    {"name":"Iran","id":"553"},
    {"name":"Islamic State of Afghanistan","id":"480"},
    {"name":"People's Republic of China","id":"507"},
    {"name":"Mongolia","id":"549"},
    {"name":"Syria","id":"382"},
    {"name":"Ba'athist Iraq","id":"450"},
    {"name":"Kuwait","id":"237"},
    {"name":"Bahrain","id":"161"},
    {"name":"Qatar","id":"226"},
    {"name":"United Arab Emirates","id":"308"},
    {"name":"Oman","id":"423"},
    {"name":"South Yemen","id":"415"},
    {"name":"Yemen Arab Republic","id":"363"},
    {"name":"Yemen","id":"448"},
    {"name":"Socialist Federal Republic of Yugoslavia","id":"405"},
    {"name":"West Germany","id":"404"},
    {"name":"Democratic Republic of Afghanistan","id":"482"},
    {"name":"Pakistan","id":"502"},
    {"name":"Saudi Arabia","id":"568"},
    {"name":"Lebanon","id":"219"},
    {"name":"Jordan","id":"321"},
    {"name":"Israel","id":"263"},
    {"name":"Turkish Republic of Northern Cyprus","id":"197"},
    {"name":"Cyprus","id":"210"},
    {"name":"Albania","id":"265"},
    {"name":"People's Socialist Republic of Albania","id":"264"},
    {"name":"Bosnia and Herzegovina","id":"293"},
    {"name":"Croatia","id":"296"},
    {"name":"Netherlands","id":"274"},
    {"name":"Belgium","id":"267"},
    {"name":"Denmark","id":"281"},
    {"name":"Egypt","id":"516"},
    {"name":"France","id":"465"},
    {"name":"Italy","id":"421"},
    {"name":"Switzerland","id":"280"},
    {"name":"Luxembourg","id":"189"},
    {"name":"India","id":"581"},
    {"name":"Transnistria","id":"201"},
    {"name":"Sudan","id":"577"},
    {"name":"Libyan Arab Jamahiriya","id":"556"},
    {"name":"Ethiopia","id":"541"},
    {"name":"United Kingdom","id":"402"}
]

# %%
neighbours_id = { rec['id']: rec for rec in neighbours}

# %%
#neighbours_id

# %% [markdown]
# #### 1988 / 1993 MAPS

# %% [markdown]
# #### 1993

# %%
with open('data/map-1993.json', 'r') as f:
    map_1991 = json.load(f)

# %%
features_filt = []
for rec in map_1991['features']:
    try:
        iso = pycountry.countries.search_fuzzy(rec["properties"]['name'])[0].alpha_3
        if iso in iso_codes.keys():
            rec["properties"]['iso'] = iso
            rec["properties"]['group'] = 'FSU-B' if iso_codes[iso]['region'] == 'Baltic states' else iso_codes[iso]['group']
            rec["properties"]['region'] = iso_codes[iso]['region']
            features_filt.append(rec)
    except LookupError as e:
        rec["properties"]['iso'] = None
        
    if rec["properties"]['id'] in neighbours_id.keys():
        rec["properties"]['iso'] = iso
        rec["properties"]['group'] = 'NGHBR'
        rec["properties"]['region'] = 'Neighbour'
        features_filt.append(rec)

# %%
len(features_filt)
# Out:
# 67

# %%
map_1991['features'] = features_filt

# %%
with open('data/app/map-1993-s.json', 'w') as f:
    json.dump(map_1991, f)

# %% [markdown]
# #### 1988

# %%
with open('data/map-1988.json', 'r') as f:
    map_1988 = json.load(f)

# %%
soviet_block = [
    {"name":"Soviet Union","id":"590", "group": "FSU", 'region': 'Eastern Europe'},
    {"name":"German Democratic Republic","id":"336", "group": "FWT", 'region': 'Eastern Europe'},
    {'name': 'Bulgaria', "id":"339", 'region': 'Eastern Europe', "group": "FWT"},
    {"name": "Czechoslovakia","id":"355", 'region': 'Eastern Europe', "group": "FWT"},
    {'name': 'Hungary', "id":"325", 'region': 'Eastern Europe', "group": "FWT"},
    {'name': 'Poland', "id":"424", 'region': 'Eastern Europe', "group": "FWT"},
    {'name': 'Romania', "id":"397", 'region': 'Eastern Europe', "group": "FWT"},
]

# %%
soviet_block_id = { rec['id']: rec for rec in soviet_block}

# %%
soviet_block_id
# Out:
# {'590': {'name': 'Soviet Union',
#   'id': '590',
#   'group': 'FSU',
#   'region': 'Eastern Europe'},
#  '336': {'name': 'German Democratic Republic',
#   'id': '336',
#   'group': 'FWT',
#   'region': 'Eastern Europe'},
#  '339': {'name': 'Bulgaria',
#   'id': '339',
#   'region': 'Eastern Europe',
#   'group': 'FWT'},
#  '355': {'name': 'Czechoslovakia',
#   'id': '355',
#   'region': 'Eastern Europe',
#   'group': 'FWT'},
#  '325': {'name': 'Hungary',
#   'id': '325',
#   'region': 'Eastern Europe',
#   'group': 'FWT'},
#  '424': {'name': 'Poland',
#   'id': '424',
#   'region': 'Eastern Europe',
#   'group': 'FWT'},
#  '397': {'name': 'Romania',
#   'id': '397',
#   'region': 'Eastern Europe',
#   'group': 'FWT'}}

# %%
features_filt = []
for rec in map_1988['features']:
    cid = rec["properties"]['id']
    if cid == "590":
        print('Soviet')
    if cid in soviet_block_id.keys():
        rec["properties"]['group'] = soviet_block_id[cid]['group']
        rec["properties"]['region'] = soviet_block_id[cid]['region']
        
        # replace Hungary name
        if cid == '325':
            rec["properties"]['name'] = soviet_block_id[cid]['name']
            
        # replace East Germany
        if cid == '336':
            rec["properties"]['name'] = 'East Germany'
            
        features_filt.append(rec)
    
    if cid in neighbours_id.keys():
        rec["properties"]['group'] = 'NGHBR'
        rec["properties"]['region'] = 'Neighbour'
        features_filt.append(rec)
        
map_1988['features'] = features_filt
# Out:
# Soviet

# %%
len(features_filt)
# Out:
# 48

# %%
with open('data/app/map-1988-s.json', 'w') as f:
    json.dump(map_1988, f)

# %% [markdown]
# #### DOWNLOAD DATA

# %%
iso_codes = list(map(lambda x: x['iso'], fsu_countries + fwt_countries))

use_cols = [
    'Country Name',
    'Country Code',
    'Indicator Code'
] + list(map(lambda x: str(x), range(1990, 2021)))

# %%
# GDP per capita growth (annual %)
gdp_pc_grw = pd.read_csv(
    'data/API_NY.GDP.PCAP.KD.ZG_DS2_en_csv_v2_3634329.csv',
    sep=',',
    skiprows=4,
    usecols = use_cols
)

gdp_pc_grw = gdp_pc_grw.loc[
    gdp_pc_grw['Country Code'].isin(iso_codes + ['EUU', 'ECS', 'ECA'])
]

# %%
# GDP per capita, PPP (constant 2017 international $)
gdp_pc_ppp = pd.read_csv(
    'data/API_NY.GDP.PCAP.PP.KD_DS2_en_csv_v2_3682444.csv',
    sep=',',
    skiprows=4,
    usecols = use_cols
)

gdp_pc_ppp = gdp_pc_ppp.loc[
    gdp_pc_ppp['Country Code'].isin(iso_codes + ['EUU', 'ECS', 'ECA'])
]

# %%
# Population, total
pop = pd.read_csv(
    'data/API_SP.POP.TOTL_DS2_en_csv_v2_3628828.csv',
    sep=',',
    skiprows=4,
    usecols = use_cols
)

pop = pop.loc[
    pop['Country Code'].isin(iso_codes + ['EUU', 'ECS', 'ECA'])
]

# %%
pop.head()
# Out:
#       Country Name Country Code Indicator Code        1990        1991  \
# 10         Armenia          ARM    SP.POP.TOTL   3538164.0   3505249.0
# 15      Azerbaijan          AZE    SP.POP.TOTL   7175200.0   7271300.0
# 21        Bulgaria          BGR    SP.POP.TOTL   8718289.0   8632367.0
# 25         Belarus          BLR    SP.POP.TOTL  10189348.0  10194050.0
# 54  Czech Republic          CZE    SP.POP.TOTL  10333355.0  10308578.0
#
#           1992        1993        1994        1995        1996  ...  \
# 10   3442820.0   3363111.0   3283664.0   3217349.0   3168213.0  ...
# 15   7382050.0   7494800.0   7596550.0   7684850.0   7763000.0  ...
# 21   8540164.0   8472313.0   8443591.0   8406067.0   8362826.0  ...
# 25  10216470.0  10239050.0  10226955.0  10193831.0  10159569.0  ...
# 54  10319123.0  10329855.0  10333587.0  10327253.0  10315241.0  ...
#
#           2011        2012        2013        2014        2015        2016  \
# 10   2876536.0   2884239.0   2897593.0   2912403.0   2925559.0   2936147.0
# 15   9173082.0   9295784.0   9416801.0   9535079.0   9649341.0   9757812.0
# 21   7348328.0   7305888.0   7265115.0   7223938.0   7177991.0   7127822.0
# 25   9461643.0   9446836.0   9443211.0   9448515.0   9461076.0   9469379.0
# 54  10496088.0  10510785.0  10514272.0  10525347.0  10546059.0  10566332.0
#
#           2017        2018        2019        2020
# 10   2944789.0   2951741.0   2957728.0   2963234.0
# 15   9854033.0   9939771.0  10024283.0  10093121.0
# 21   7075947.0   7025037.0   6975761.0   6934015.0
# 25   9458989.0   9438785.0   9419758.0   9379952.0
# 54  10594438.0  10629928.0  10671870.0  10698896.0
#
# [5 rows x 34 columns]

# %%
countries_df = pd.DataFrame(
    fwt_countries + fsu_countries
).rename(columns={
    'name': 'Country Name',
    'region': 'Region',
    'iso': 'Country Code',
    'group': 'Group'
})

# %%
# Merge with countries
pop = pop.merge(countries_df.loc[:, ['Group', 'Country Code', 'Region']], on = 'Country Code', how ='left')
gdp_pc_ppp = gdp_pc_ppp.merge(countries_df.loc[:, ['Group', 'Country Code', 'Region']], on = 'Country Code', how ='left')
gdp_pc_grw = gdp_pc_grw.merge(countries_df.loc[:, ['Group', 'Country Code', 'Region']], on = 'Country Code', how ='left')

# %%
# Wide to long format
pop = pd.melt(
    pop,
    id_vars = [
        'Country Name',
        'Country Code',
        'Indicator Code',
        'Group',
        'Region'
    ],
    var_name = 'Year',
    value_name = 'Value'
)

gdp_pc_ppp = pd.melt(
    gdp_pc_ppp,
    id_vars = [
        'Country Name',
        'Country Code',
        'Indicator Code',
        'Group',
        'Region'
    ],
    var_name = 'Year',
    value_name = 'Value'
)

gdp_pc_grw = pd.melt(
    gdp_pc_grw,
    id_vars = [
        'Country Name',
        'Country Code',
        'Indicator Code',
        'Group',
        'Region'
    ],
    var_name = 'Year',
    value_name = 'Value'
)

# %%
pop.loc[:, 'Year'] = pd.to_numeric(pop.Year)
gdp_pc_ppp.loc[:, 'Year'] = pd.to_numeric(gdp_pc_ppp.Year)
gdp_pc_grw.loc[:, 'Year'] = pd.to_numeric(gdp_pc_grw.Year)

# %% [markdown]
# ### NAs

# %%
gdp_pc_ppp.loc[
    gdp_pc_ppp.Value.isna()
]
# Out:
#         Country Name Country Code     Indicator Code Group          Region  \
# 7            Estonia          EST  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 10           Hungary          HUN  NY.GDP.PCAP.PP.KD   FWT  Eastern Europe
# 13         Lithuania          LTU  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 14            Latvia          LVA  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 15           Moldova          MDA  NY.GDP.PCAP.PP.KD   FSU  Eastern Europe
# 19   Slovak Republic          SVK  NY.GDP.PCAP.PP.KD   FWT  Eastern Europe
# 31           Estonia          EST  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 37         Lithuania          LTU  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 38            Latvia          LVA  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 39           Moldova          MDA  NY.GDP.PCAP.PP.KD   FSU  Eastern Europe
# 43   Slovak Republic          SVK  NY.GDP.PCAP.PP.KD   FWT  Eastern Europe
# 55           Estonia          EST  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 61         Lithuania          LTU  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 62            Latvia          LVA  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 63           Moldova          MDA  NY.GDP.PCAP.PP.KD   FSU  Eastern Europe
# 79           Estonia          EST  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 85         Lithuania          LTU  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 86            Latvia          LVA  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 87           Moldova          MDA  NY.GDP.PCAP.PP.KD   FSU  Eastern Europe
# 103          Estonia          EST  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 109        Lithuania          LTU  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 110           Latvia          LVA  NY.GDP.PCAP.PP.KD   FSU   Baltic states
# 111          Moldova          MDA  NY.GDP.PCAP.PP.KD   FSU  Eastern Europe
# 741     Turkmenistan          TKM  NY.GDP.PCAP.PP.KD   FSU    Central Asia
#
#      Year  Value
# 7    1990    NaN
# 10   1990    NaN
# 13   1990    NaN
# 14   1990    NaN
# 15   1990    NaN
# 19   1990    NaN
# 31   1991    NaN
# 37   1991    NaN
# 38   1991    NaN
# 39   1991    NaN
# 43   1991    NaN
# 55   1992    NaN
# 61   1992    NaN
# 62   1992    NaN
# 63   1992    NaN
# 79   1993    NaN
# 85   1993    NaN
# 86   1993    NaN
# 87   1993    NaN
# 103  1994    NaN
# 109  1994    NaN
# 110  1994    NaN
# 111  1994    NaN
# 741  2020    NaN

# %%
gdp_pc_ppp.loc[
    gdp_pc_ppp.Value.isna(),
    'Country Name'
].value_counts()
# Out:
# Estonia            5
# Lithuania          5
# Latvia             5
# Moldova            5
# Slovak Republic    2
# Hungary            1
# Turkmenistan       1
# Name: Country Name, dtype: int64

# %% [markdown]
# #### IMPUTE NAs WITH GAPMINDER DATA

# %%
gdp_pc_ppp_gm = pd.read_csv(
    'data/GM-GDP per capita - Dataset - v27 - data-GDP-per-capita-in-columns.csv',
    sep=',',
    skiprows=3,
    usecols = [
        'geo', 'Country Name', '1990', '1991', '1992', '1993', '1994', '2020'
    ]
)

# %%
fill_df = gdp_pc_ppp_gm.loc[
    gdp_pc_ppp_gm['Country Name'].isin(
        gdp_pc_ppp.loc[
            gdp_pc_ppp.Value.isna(),
            'Country Name'
        ]
    )
].melt(id_vars = ['Country Name', 'geo'], var_name = 'Year', value_name = 'Value')

fill_df.loc[:, 'Year'] = pd.to_numeric(fill_df.loc[:, 'Year'])

# %%
fill_df.dtypes
# Out:
# Country Name     object
# geo              object
# Year              int64
# Value           float64
# dtype: object

# %%
gdp_pc_ppp = gdp_pc_ppp.merge(
    fill_df.loc[:, ['Country Name', 'Year', 'Value']],
    on = ['Country Name', 'Year'],
    how = 'left',
    suffixes = ['', '_fill']
)

# %%
gdp_pc_ppp.loc[
    gdp_pc_ppp.Value.isna(),
    'Value'
] = gdp_pc_ppp.loc[
    gdp_pc_ppp.Value.isna(),
    'Value_fill'
]

# %%
gdp_pc_ppp.drop('Value_fill', axis=1, inplace=True)

# %%
gdp_pc_ppp.loc[
    gdp_pc_ppp.Value.isna()
]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Code, Group, Region, Year, Value]
# Index: []

# %% [markdown]
# ### EDA

# %% [markdown]
# #### GDP PPC

# %%
df = gdp_pc_ppp.loc[
    gdp_pc_ppp.Year.isin([1991, 2020])
].copy()

df.loc[
    df.Region == 'Baltic states',
    'Group'
] = 'FSU-B'

# Add Pct Change and Labels
pct_change = df.groupby('Country Code').apply(
    lambda tx: tx.sort_values(by='Year').loc[:, ['Value']].pct_change().iloc[1] * 100
).rename(columns = {'Value': 'PctChange'})

df = df.merge(pct_change, on = 'Country Code')

df.loc[:, 'Label'] = df.loc[:, 'Country Name'] + ' ↓' + df.loc[:, 'PctChange'].round(2).astype(str) + '%'
df.loc[df.PctChange>0, 'Label'] = df.loc[:, 'Country Name'] + ' ↑+' + df.loc[:, 'PctChange'].round(2).astype(str) + '%'


x = 'Year:O'
y = 'Value'
detail = 'Country Code'

color_fwt = alt.Color(
    'Group',
    scale = alt.Scale(
    domain = ['FWT', 'FSU', 'FSU-B', 'null'],
    range = ['#D50000', '#E0E0E0', '#E0E0E0', '#212121']
    ),
    legend=alt.Legend(orient="top")
)

color_fsu = alt.Color(
    'Group',
    scale = alt.Scale(
    domain = ['FWT', 'FSU', 'FSU-B', 'null'],
    range = ['#E0E0E0', '#D50000', '#E0E0E0', '#212121']
    ),
    legend=alt.Legend(orient="top")
)

color_fsu_b = alt.Color(
    'Group',
    scale = alt.Scale(
    domain = ['FWT', 'FSU', 'FSU-B', 'null'],
    range = ['#E0E0E0', '#E0E0E0', '#D50000', '#212121']
    ),
    legend=alt.Legend(orient="top")
)

text = alt.condition(alt.datum.Year == 2020, 'Label', alt.value(' '))

width = 250
height = 550

# FWT

base_fwt = alt.Chart(
    df.loc[
        ~df['Country Code'].isin(['FSU', 'FSU-B', 'ECS', 'ECA'])
    ]
).encode(
    x=x,
    y=y,
    color=color_fwt,
    detail=detail,
    text=text
)

slope_fwt = alt.layer(
    base_fwt.mark_line(),
    base_fwt.mark_circle(),
    base_fwt.mark_text(
        align='left',
        baseline='middle',
        dx=15  # Nudges text to right so it doesn't appear on top of the bar
    )
).properties(
    width = width,
    height = height
)

# FSU

base_fsu = alt.Chart(
    df.loc[
        ~df['Country Code'].isin(['FWT', 'FSU-B', 'EUU', 'ECA'])
    ]
).encode(
    x=x,
    y=y,
    color=color_fsu,
    detail=detail,
    text=text
)

slope_fsu = alt.layer(
    base_fsu.mark_line(),
    base_fsu.mark_circle(),
    base_fsu.mark_text(
        align='left',
        baseline='middle',
        dx=15  # Nudges text to right so it doesn't appear on top of the bar
    )
).properties(
    width = width,
    height = height
)


# FSU - B

base_fsu_b = alt.Chart(
    df.loc[
        ~df['Country Code'].isin(['FWT', 'FSU', 'ECS', 'ECA'])
    ]
).encode(
    x=x,
    y=y,
    color=color_fsu_b,
    detail=detail,
    text=text
)

slope_fsu_b = alt.layer(
    base_fsu_b.mark_line(),
    base_fsu_b.mark_circle(),
    base_fsu_b.mark_text(
        align='left',
        baseline='middle',
        dx=15  # Nudges text to right so it doesn't appear on top of the bar
    )
).properties(
    width = width,
    height = height
)

alt.hconcat(
    slope_fsu,
    slope_fsu_b,
    slope_fwt
).configure_view(
    strokeWidth=0
).configure_axis(
    grid=False
).resolve_scale(color='independent', y='shared')
# Out:
# alt.HConcatChart(...)

# %%
x = 'Country Code'
y = 'Value'
color = 'PeriodChg'
detail = 'Country Code'

chart_df = gdp_pc_ppp.loc[
    gdp_pc_ppp.Year.isin([1990, 2020])
].copy()

change = chart_df.groupby('Country Code').apply(
    lambda tx: tx.sort_values(by='Year').loc[:, ['Value']].diff().iloc[1] > 0
).rename(columns = {'Value': 'PeriodChg'})

chart_df = chart_df.merge(change, on = 'Country Code')

width = 250
height = 500

df = gdp_pc_ppp.loc[
    ~gdp_pc_ppp.Group.isin(['FSU']) & \
    gdp_pc_ppp.Year.isin([1990, 2020])
].copy()

base = alt.Chart(
    chart_df.loc[
        ~chart_df.Group.isin(['FSU'])
    ]
).encode(
    x=x,
    y=y,
    color=color,
    detail=detail
)

fwt_slope = alt.layer(
    base.mark_line(),
    base.mark_circle()
).properties(
    width = width,
    height = height
)

base = alt.Chart(
    chart_df.loc[
        ~chart_df.Group.isin(['FWT'])
    ]
).encode(
    x=x,
    y=y,
    color=color,
    detail=detail
)

fsu_slope = alt.layer(
    base.mark_line(),
    base.mark_circle()
).properties(
    width = width,
    height = height
)

alt.hconcat(
    fwt_slope,
    fsu_slope
)
# Out:
# alt.HConcatChart(...)

# %%
gdppc_ts_df = wb.data.DataFrame('NY.GDP.PCAP.PP.KD', iso_codes, time=range(1991, 2021), labels=True, skipAggs=True)

# %%
gdppc_ts = gdppc_ts_df.reset_index().rename(columns={'index': 'Country Code', 'Country': 'Country Name'})
gdppc_ts = pd.wide_to_long(gdppc_ts, 'YR', i='Country Code', j='Year').reset_index().rename(columns={'YR': 'Value'})
gdppc_ts = gdppc_ts.merge(countries_df.drop(['independence', 'Country Name'], axis=1), how='left', on='Country Code')

gdppc_ts.loc[gdppc_ts['Country Code'].isin(['LTU', 'LVA', 'EST']), 'Group'] = 'FSU-B'

# %%
gdppc_ts
# Out:
#     Country Code  Year        Country Name         Value          Region  \
# 0            ROU  1991             Romania  11685.090983  Eastern Europe
# 1            POL  1991              Poland  10483.901554  Eastern Europe
# 2            HUN  1991             Hungary  16432.105131  Eastern Europe
# 3            CZE  1991      Czech Republic  20895.879761  Eastern Europe
# 4            SVK  1991     Slovak Republic           NaN  Eastern Europe
# ..           ...   ...                 ...           ...             ...
# 625          LVA  2020              Latvia  30100.268811   Baltic states
# 626          LTU  2020           Lithuania  37107.056641   Baltic states
# 627          BLR  2020             Belarus  19186.775815  Eastern Europe
# 628          UKR  2020             Ukraine  12375.921478  Eastern Europe
# 629          RUS  2020  Russian Federation  26456.387938  Eastern Europe
#
#      Group
# 0      FWT
# 1      FWT
# 2      FWT
# 3      FWT
# 4      FWT
# ..     ...
# 625  FSU-B
# 626  FSU-B
# 627    FSU
# 628    FSU
# 629    FSU
#
# [630 rows x 6 columns]

# %%
alt.Chart(gdppc_ts).mark_line().encode(
    x=alt.X('Year:Q', axis=alt.Axis(tickCount=5, grid=False)),
    y=alt.Y('Value', scale=alt.Scale(nice=False)),
    detail='Country Name',
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
).properties(
    width=250,
    height=250
).facet(
    column='Group:N'
)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# #### GDP GROWTH (annual %)

# %%
# NY.GDP.MKTP.KD.ZG

gdpchg_df = wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', iso_codes + ['EUU'], time=range(1991, 2021), labels=True, skipAggs=False)

# %%
gdpchg = gdpchg_df.reset_index().rename(columns={'index': 'Country Code', 'Country': 'Country Name'})
gdpchg = pd.wide_to_long(gdpchg, 'YR', i='Country Code', j='Year').reset_index().rename(columns={'YR': 'Value'})
gdpchg = gdpchg.merge(countries_df.drop(['independence', 'Country Name'], axis=1), how='left', on='Country Code')

gdpchg.loc[gdpchg['Country Code'].isin(['LTU', 'LVA', 'EST']), 'Group'] = 'FSU-B'
gdpchg.loc[gdpchg['Country Code'].isin(['EUU']), 'Group'] = 'EUU'

# %%
gdpchg.loc[gdpchg.Value.isna()]
# Out:
#     Country Code  Year     Country Name  Value          Region  Group
# 3            HUN  1991          Hungary    NaN  Eastern Europe    FWT
# 5            SVK  1991  Slovak Republic    NaN  Eastern Europe    FWT
# 15           MDA  1991          Moldova    NaN  Eastern Europe    FSU
# 16           EST  1991          Estonia    NaN   Baltic states  FSU-B
# 17           LVA  1991           Latvia    NaN   Baltic states  FSU-B
# 18           LTU  1991        Lithuania    NaN   Baltic states  FSU-B
# 27           SVK  1992  Slovak Republic    NaN  Eastern Europe    FWT
# 37           MDA  1992          Moldova    NaN  Eastern Europe    FSU
# 38           EST  1992          Estonia    NaN   Baltic states  FSU-B
# 39           LVA  1992           Latvia    NaN   Baltic states  FSU-B
# 40           LTU  1992        Lithuania    NaN   Baltic states  FSU-B
# 59           MDA  1993          Moldova    NaN  Eastern Europe    FSU
# 60           EST  1993          Estonia    NaN   Baltic states  FSU-B
# 61           LVA  1993           Latvia    NaN   Baltic states  FSU-B
# 62           LTU  1993        Lithuania    NaN   Baltic states  FSU-B
# 81           MDA  1994          Moldova    NaN  Eastern Europe    FSU
# 82           EST  1994          Estonia    NaN   Baltic states  FSU-B
# 83           LVA  1994           Latvia    NaN   Baltic states  FSU-B
# 84           LTU  1994        Lithuania    NaN   Baltic states  FSU-B
# 103          MDA  1995          Moldova    NaN  Eastern Europe    FSU
# 104          EST  1995          Estonia    NaN   Baltic states  FSU-B
# 105          LVA  1995           Latvia    NaN   Baltic states  FSU-B
# 106          LTU  1995        Lithuania    NaN   Baltic states  FSU-B
# 648          TKM  2020     Turkmenistan    NaN    Central Asia    FSU

# %%
dots = alt.Chart().mark_circle(orient='horizontal', opacity=0.5, size=75).encode(
    x=alt.X('Year:N', scale=alt.Scale(domain=list(range(1991, 2021)), nice=True), axis=alt.Axis(grid=True)),
    y=alt.Y('Value', scale=alt.Scale(nice=True), axis=alt.Axis(grid=False)),
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
).properties(
    width=350,
    height=350
)

line = alt.Chart().mark_line(color='#D50000').encode(
    x=alt.X('Year:N', scale=alt.Scale(domain=list(range(1991, 2021)), nice=True), axis=alt.Axis(grid=True)),
    y=alt.Y('mean(Value)', scale=alt.Scale(nice=True), axis=alt.Axis(grid=False)),
    #color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
).properties(
    width=350,
    height=350
)

alt.layer(dots, line, data=gdpchg.loc[gdpchg.Group!='EUU']).facet(
    column='Group:N'
)
# Out:
# alt.FacetChart(...)

# %%
alt.Chart(gdpchg).mark_line().encode(
    x=alt.X('Year:N', scale=alt.Scale(domain=list(range(1991, 2021)), nice=True), axis=alt.Axis(grid=True)),
    y=alt.Y('mean(Value)', scale=alt.Scale(nice=True), axis=alt.Axis(grid=False)),
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT', 'EUU'], range=['#800000', '#D3543F', '#FFB495', '#212121']))
).properties(
    width=350,
    height=350
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(gdpchg).mark_line().encode(
    x=alt.X('Year:Q', axis=alt.Axis(tickCount=5, grid=False)),
    y=alt.Y('Value', scale=alt.Scale(nice=False)),
    detail='Country Name',
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
).properties(
    width=250,
    height=250
).facet(
    column='Group:N'
)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# #### EMPLOYMENT/UNEMPLOYMENT

# %%
# SL.EMP.TOTL.SP.NE.ZS - Employment to population ratio, 15+, total (%) (national estimate)
# SL.EMP.TOTL.SP.ZS - (modeled ILO estimate)
# SL.UEM.TOTL.ZS - Unemployment, total (% of total labor force) (modeled ILO estimate)

empl_df = wb.data.DataFrame('SL.UEM.TOTL.ZS', iso_codes, time=range(1991, 2021), labels=True, skipAggs=True)

# %%
empl_ts = empl_df.reset_index().rename(columns={'index': 'Country Code', 'Country': 'Country Name'})
empl_ts = pd.wide_to_long(empl_ts, 'YR', i='Country Code', j='Year').reset_index().rename(columns={'YR': 'Value'})
empl_ts = empl_ts.merge(countries_df.drop(['independence', 'Country Name'], axis=1), how='left', on='Country Code')

empl_ts.loc[empl_ts['Country Code'].isin(['LTU', 'LVA', 'EST']), 'Group'] = 'FSU-B'

# %%
alt.Chart(empl_ts).mark_line().encode(
    x=alt.X('Year:Q', axis=alt.Axis(tickCount=5, grid=False)),
    y=alt.Y('Value', scale=alt.Scale(nice=False)),
    detail='Country Name',
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495'])),
    tooltip = ['Country Code']
).properties(
    width=250,
    height=250
).facet(
    column='Group:N'
).interactive()
# Out:
# alt.FacetChart(...)

# %% [markdown]
# #### SAVE DATA FOR APP

# %%
app_df = gdp_pc_ppp.loc[
    gdp_pc_ppp.Year.isin([1991, 2020])
].copy()

app_df.loc[
    app_df.Region == 'Baltic states',
    'Group'
] = 'FSU-B'

# Add Pct Change and Labels
pct_change = app_df.groupby('Country Code').apply(
    lambda tx: tx.sort_values(by='Year').loc[:, ['Value']].pct_change().iloc[1] * 100
).rename(columns = {'Value': 'PctChange'})

app_df = app_df.merge(pct_change, on = 'Country Code')

app_df.loc[:, 'Indicator Code'] = 'GDP_PPC'

# %%
app_df
# Out:
#                                      Country Name Country Code Indicator Code  \
# 0                                         Armenia          ARM        GDP_PPC
# 1                                         Armenia          ARM        GDP_PPC
# 2                                      Azerbaijan          AZE        GDP_PPC
# 3                                      Azerbaijan          AZE        GDP_PPC
# 4                                        Bulgaria          BGR        GDP_PPC
# 5                                        Bulgaria          BGR        GDP_PPC
# 6                                         Belarus          BLR        GDP_PPC
# 7                                         Belarus          BLR        GDP_PPC
# 8                                  Czech Republic          CZE        GDP_PPC
# 9                                  Czech Republic          CZE        GDP_PPC
# 10  Europe & Central Asia (excluding high income)          ECA        GDP_PPC
# 11  Europe & Central Asia (excluding high income)          ECA        GDP_PPC
# 12                          Europe & Central Asia          ECS        GDP_PPC
# 13                          Europe & Central Asia          ECS        GDP_PPC
# 14                                        Estonia          EST        GDP_PPC
# 15                                        Estonia          EST        GDP_PPC
# 16                                 European Union          EUU        GDP_PPC
# 17                                 European Union          EUU        GDP_PPC
# 18                                        Georgia          GEO        GDP_PPC
# 19                                        Georgia          GEO        GDP_PPC
# 20                                        Hungary          HUN        GDP_PPC
# 21                                        Hungary          HUN        GDP_PPC
# 22                                     Kazakhstan          KAZ        GDP_PPC
# 23                                     Kazakhstan          KAZ        GDP_PPC
# 24                                Kyrgyz Republic          KGZ        GDP_PPC
# 25                                Kyrgyz Republic          KGZ        GDP_PPC
# 26                                      Lithuania          LTU        GDP_PPC
# 27                                      Lithuania          LTU        GDP_PPC
# 28                                         Latvia          LVA        GDP_PPC
# 29                                         Latvia          LVA        GDP_PPC
# 30                                        Moldova          MDA        GDP_PPC
# 31                                        Moldova          MDA        GDP_PPC
# 32                                         Poland          POL        GDP_PPC
# 33                                         Poland          POL        GDP_PPC
# 34                                        Romania          ROU        GDP_PPC
# 35                                        Romania          ROU        GDP_PPC
# 36                             Russian Federation          RUS        GDP_PPC
# 37                             Russian Federation          RUS        GDP_PPC
# 38                                Slovak Republic          SVK        GDP_PPC
# 39                                Slovak Republic          SVK        GDP_PPC
# 40                                     Tajikistan          TJK        GDP_PPC
# 41                                     Tajikistan          TJK        GDP_PPC
# 42                                   Turkmenistan          TKM        GDP_PPC
# 43                                   Turkmenistan          TKM        GDP_PPC
# 44                                        Ukraine          UKR        GDP_PPC
# 45                                        Ukraine          UKR        GDP_PPC
# 46                                     Uzbekistan          UZB        GDP_PPC
# 47                                     Uzbekistan          UZB        GDP_PPC
#
#     Group          Region  Year         Value   PctChange
# 0     FSU  South Caucasus  1991   4616.944854  173.338594
# 1     FSU  South Caucasus  2020  12619.892154  173.338594
# 2     FSU  South Caucasus  1991   7463.628859   83.915491
# 3     FSU  South Caucasus  2020  13726.769663   83.915491
# 4     FWT  Eastern Europe  1991  11565.373838   93.500830
# 5     FWT  Eastern Europe  2020  22379.094313   93.500830
# 6     FSU  Eastern Europe  1991   8784.377365  118.419303
# 7     FSU  Eastern Europe  2020  19186.775815  118.419303
# 8     FWT  Eastern Europe  1991  20895.879761   84.282897
# 9     FWT  Eastern Europe  2020  38507.532644   84.282897
# 10    NaN             NaN  1991  14378.373043   50.549332
# 11    NaN             NaN  2020  21646.544502   50.549332
# 12    NaN             NaN  1991  23305.712901   43.608294
# 13    NaN             NaN  2020  33468.936732   43.608294
# 14  FSU-B   Baltic states  1991  15053.000000  133.942495
# 15  FSU-B   Baltic states  2020  35215.363816  133.942495
# 16    NaN             NaN  1991  28839.027789   44.539872
# 17    NaN             NaN  2020  41683.893973   44.539872
# 18    FSU  South Caucasus  1991   8724.290499   60.461214
# 19    FSU  South Caucasus  2020  13999.102453   60.461214
# 20    FWT  Eastern Europe  1991  16432.105131   89.261372
# 21    FWT  Eastern Europe  2020  31099.627601   89.261372
# 22    FSU    Central Asia  1991  11917.714050  112.819051
# 23    FSU    Central Asia  2020  25363.165903  112.819051
# 24    FSU    Central Asia  1991   4671.522850    0.750235
# 25    FSU    Central Asia  2020   4706.570237    0.750235
# 26  FSU-B   Baltic states  1991  16483.000000  125.138100
# 27  FSU-B   Baltic states  2020  37109.513007  125.138100
# 28  FSU-B   Baltic states  1991  15185.000000   98.109136
# 29  FSU-B   Baltic states  2020  30082.872355   98.109136
# 30    FSU  Eastern Europe  1991  12259.000000    0.533394
# 31    FSU  Eastern Europe  2020  12324.388726    0.533394
# 32    FWT  Eastern Europe  1991  10483.901554  208.611645
# 33    FWT  Eastern Europe  2020  32354.540998  208.611645
# 34    FWT  Eastern Europe  1991  11685.090983  146.708494
# 35    FWT  Eastern Europe  2020  28828.112040  146.708494
# 36    FSU  Eastern Europe  1991  20340.131915   30.069894
# 37    FSU  Eastern Europe  2020  26456.387938   30.069894
# 38    FWT  Eastern Europe  1991  12546.000000  143.183240
# 39    FWT  Eastern Europe  2020  30509.769324  143.183240
# 40    FSU    Central Asia  1991   3720.018892   -1.678631
# 41    FSU    Central Asia  2020   3657.573507   -1.678631
# 42    FSU    Central Asia  1991   6685.071968  131.007236
# 43    FSU    Central Asia  2020  15443.000000  131.007236
# 44    FSU  Eastern Europe  1991  14967.733421  -17.315995
# 45    FSU  Eastern Europe  2020  12375.921478  -17.315995
# 46    FSU    Central Asia  1991   3544.586094  106.846718
# 47    FSU    Central Asia  2020   7331.859994  106.846718

# %%
app_df = app_df.rename(columns = {
    'Country Name': 'countryName',
    'Country Code': 'countryCode',
    'Indicator Code': 'indicatorCode',
    'Group': 'group',
    'Region': 'region',
    'Year': 'year',
    'Value': 'value',
    'PctChange': 'pctChange'
})

# %%
#app_df.to_json('data/app/GDPPPC.json', orient='records')

# %% [markdown]
# #### DEMOGRAPHICS - POPULATION

# %%
df = pop.loc[
    pop.Year.isin([1991, 2020])
].copy()

df.loc[
    df.Region == 'Baltic states',
    'Group'
] = 'FSU-B'

# Add Pct Change and Labels
pct_change = df.groupby('Country Code').apply(
    lambda tx: tx.sort_values(by='Year').loc[:, ['Value']].pct_change().iloc[1] * 100
).rename(columns = {'Value': 'PctChange'})

df = df.merge(pct_change, on = 'Country Code')

df.loc[:, 'Label'] = df.loc[:, 'Country Name'] + ' ↓' + df.loc[:, 'PctChange'].round(2).astype(str) + '%'
df.loc[df.PctChange>0, 'Label'] = df.loc[:, 'Country Name'] + ' ↑+' + df.loc[:, 'PctChange'].round(2).astype(str) + '%'


x = 'Year:O'
y = alt.Y('Value', scale=alt.Scale(type="log"))
detail = 'Country Code'

color_fwt = alt.Color(
    'Group',
    scale = alt.Scale(
    domain = ['FWT', 'FSU', 'FSU-B', 'null'],
    range = ['#D50000', '#E0E0E0', '#E0E0E0', '#212121']
    ),
    legend=alt.Legend(orient="top")
)

color_fsu = alt.Color(
    'Group',
    scale = alt.Scale(
    domain = ['FWT', 'FSU', 'FSU-B', 'null'],
    range = ['#E0E0E0', '#D50000', '#E0E0E0', '#212121']
    ),
    legend=alt.Legend(orient="top")
)

color_fsu_b = alt.Color(
    'Group',
    scale = alt.Scale(
    domain = ['FWT', 'FSU', 'FSU-B', 'null'],
    range = ['#E0E0E0', '#E0E0E0', '#D50000', '#212121']
    ),
    legend=alt.Legend(orient="top")
)

text = alt.condition(alt.datum.Year == 2020, 'Label', alt.value(' '))

width = 250
height = 550

# FWT

base_fwt = alt.Chart(
    df.loc[
        ~df['Country Code'].isin(['FSU', 'FSU-B', 'ECS', 'ECA'])
    ]
).encode(
    x=x,
    y=y,
    color=color_fwt,
    detail=detail,
    text=text
)

slope_fwt = alt.layer(
    base_fwt.mark_line(),
    base_fwt.mark_circle(),
    base_fwt.mark_text(
        align='left',
        baseline='middle',
        dx=15  # Nudges text to right so it doesn't appear on top of the bar
    )
).properties(
    width = width,
    height = height
)

# FSU

base_fsu = alt.Chart(
    df.loc[
        ~df['Country Code'].isin(['FWT', 'FSU-B', 'EUU', 'ECA'])
    ]
).encode(
    x=x,
    y=y,
    color=color_fsu,
    detail=detail,
    text=text
)

slope_fsu = alt.layer(
    base_fsu.mark_line(),
    base_fsu.mark_circle(),
    base_fsu.mark_text(
        align='left',
        baseline='middle',
        dx=15  # Nudges text to right so it doesn't appear on top of the bar
    )
).properties(
    width = width,
    height = height
)


# FSU - B

base_fsu_b = alt.Chart(
    df.loc[
        ~df['Country Code'].isin(['FWT', 'FSU', 'ECS', 'ECA'])
    ]
).encode(
    x=x,
    y=y,
    color=color_fsu_b,
    detail=detail,
    text=text
)

slope_fsu_b = alt.layer(
    base_fsu_b.mark_line(),
    base_fsu_b.mark_circle(),
    base_fsu_b.mark_text(
        align='left',
        baseline='middle',
        dx=15  # Nudges text to right so it doesn't appear on top of the bar
    )
).properties(
    width = width,
    height = height
)

alt.hconcat(
    slope_fsu,
    slope_fsu_b,
    slope_fwt
).configure_view(
    strokeWidth=0
).configure_axis(
    grid=False
).resolve_scale(color='independent', y='shared')
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# #### DEMOGRAPHICS - POPULATION % CHANGE 1991 - 2020

# %%
sort = alt.EncodingSortField('PctChange', op='min', order='descending')

pop_chg_bars = alt.Chart().mark_bar(size=1).encode(
    x=alt.X('PctChange'),
    y=alt.Y('Country Code', sort=sort),
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
)

pop_chg_circ = alt.Chart().mark_circle(size=60).encode(
    x=alt.X('PctChange'),
    y=alt.Y('Country Code', sort=sort),
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
)

alt.layer(
    pop_chg_bars,
    pop_chg_circ,
    data=df.loc[(df.Year==2020)&(~df.Group.isna())]
).properties(
    width=250,
    height=250
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### SAVE POPULATION DATA FOR APP

# %%
app_df = df.loc[(df.Year==2020)&(~df.Group.isna())].copy()

app_df = app_df.drop('Label', axis=1)

app_df.loc[:, 'Indicator Code'] = 'POP_PCT'

app_df = app_df.rename(columns = {
    'Country Name': 'countryName',
    'Country Code': 'countryCode',
    'Indicator Code': 'indicatorCode',
    'Group': 'group',
    'Region': 'region',
    'Year': 'year',
    'Value': 'value',
    'PctChange': 'pctChange'
})

# %%
app_df
# Out:
#            countryName countryCode indicatorCode  group          region  year  \
# 1              Armenia         ARM       POP_PCT    FSU  South Caucasus  2020
# 3           Azerbaijan         AZE       POP_PCT    FSU  South Caucasus  2020
# 5             Bulgaria         BGR       POP_PCT    FWT  Eastern Europe  2020
# 7              Belarus         BLR       POP_PCT    FSU  Eastern Europe  2020
# 9       Czech Republic         CZE       POP_PCT    FWT  Eastern Europe  2020
# 15             Estonia         EST       POP_PCT  FSU-B   Baltic states  2020
# 19             Georgia         GEO       POP_PCT    FSU  South Caucasus  2020
# 21             Hungary         HUN       POP_PCT    FWT  Eastern Europe  2020
# 23          Kazakhstan         KAZ       POP_PCT    FSU    Central Asia  2020
# 25     Kyrgyz Republic         KGZ       POP_PCT    FSU    Central Asia  2020
# 27           Lithuania         LTU       POP_PCT  FSU-B   Baltic states  2020
# 29              Latvia         LVA       POP_PCT  FSU-B   Baltic states  2020
# 31             Moldova         MDA       POP_PCT    FSU  Eastern Europe  2020
# 33              Poland         POL       POP_PCT    FWT  Eastern Europe  2020
# 35             Romania         ROU       POP_PCT    FWT  Eastern Europe  2020
# 37  Russian Federation         RUS       POP_PCT    FSU  Eastern Europe  2020
# 39     Slovak Republic         SVK       POP_PCT    FWT  Eastern Europe  2020
# 41          Tajikistan         TJK       POP_PCT    FSU    Central Asia  2020
# 43        Turkmenistan         TKM       POP_PCT    FSU    Central Asia  2020
# 45             Ukraine         UKR       POP_PCT    FSU  Eastern Europe  2020
# 47          Uzbekistan         UZB       POP_PCT    FSU    Central Asia  2020
#
#           value  pctChange
# 1     2963234.0 -15.462953
# 3    10093121.0  38.807655
# 5     6934015.0 -19.674233
# 7     9379952.0  -7.986011
# 9    10698896.0   3.786342
# 15    1331057.0 -14.747642
# 19    3714000.0 -23.199404
# 21    9749763.0  -6.011886
# 23   18754440.0  13.996897
# 25    6591600.0  47.674523
# 27    2794700.0 -24.551866
# 29    1901548.0 -28.259201
# 31    2620495.0 -11.931617
# 33   37950802.0  -0.772341
# 35   19286123.0 -16.151502
# 37  144104080.0  -2.891040
# 39    5458827.0   2.932762
# 41    9537642.0  76.602200
# 43    6031187.0  59.168323
# 45   44134693.0 -15.126406
# 47   34232050.0  63.383209

# %%
#app_df.to_json('data/app/POPPCT.json', orient='records')

# %% [markdown]
# ### DEMOGRAPHICS - LIFE EXPECTANCY vs MORTALITY RATE (WORLD BANK DATA API)

# %%
#iso_codes

# %%
"""
SP.DYN.LE00.IN - Life expectancy at birth, total (years)

Life expectancy at birth indicates the number of years a newborn infant
would live if prevailing patterns of mortality at the time of its birth were to stay the same throughout its life.

SP.DYN.CDRT.IN - Death rate, crude (per 1,000 people)

Crude death rate indicates the number of deaths occurring during the year, per 1,000 population estimated at midyear.
"""

dem_df = wb.data.DataFrame(['SP.DYN.LE00.IN', 'SP.DYN.CDRT.IN'], time=[1991, 2010, 2019, 2020], labels=True, skipAggs=True)

# %%
dem = dem_df.reset_index().rename(columns={'Country': 'Country Name', 'economy': 'Country Code'})
dem = dem.merge(countries_df.drop(['independence', 'Country Name'], axis=1), how='left', on='Country Code')

# %%
# Transform values from wide to long
dem = pd.wide_to_long(dem, 'YR', i=['Country Code', 'series'], j='Year').reset_index().rename(columns={'YR': 'Value'}).drop('Series', axis=1)

# %%
dem.head()
# Out:
#   Country Code          series  Year Region Country Name Group   Value
# 0          ABW  SP.DYN.CDRT.IN  1991    NaN        Aruba   NaN   7.054
# 1          ABW  SP.DYN.CDRT.IN  2010    NaN        Aruba   NaN   7.918
# 2          ABW  SP.DYN.CDRT.IN  2019    NaN        Aruba   NaN   9.205
# 3          ABW  SP.DYN.CDRT.IN  2020    NaN        Aruba   NaN   9.362
# 4          ABW  SP.DYN.LE00.IN  1991    NaN        Aruba   NaN  73.509

# %%
dem = pd.merge(
    dem.pivot_table(index=['Country Code', 'Year'], columns='series', values='Value', aggfunc='sum').reset_index(),
    dem.loc[:, ['Country Code', 'Group']].groupby('Country Code').last().reset_index(),
    on='Country Code',
    how='left'
)
#dem.pivot_table(index=['Country Code', 'Year'], columns='series', values='Value', aggfunc='sum').reset_index()

# %%
dem.head()
# Out:
#   Country Code  Year  SP.DYN.CDRT.IN  SP.DYN.LE00.IN Group
# 0          ABW  1991           7.054          73.509  None
# 1          ABW  2010           7.918          75.017  None
# 2          ABW  2019           9.205          76.293  None
# 3          ABW  2020           9.362          76.434  None
# 4          AFG  1991          14.783          50.999  None

# %%
dem = dem.rename(columns={'SP.DYN.LE00.IN': 'Life Expectancy', 'SP.DYN.CDRT.IN': 'Mortality'})

# %%
alt.Chart(
    dem.loc[dem.Year == 1991].replace(0, np.nan)
).mark_circle(size=70).encode(
    x=alt.X('Life Expectancy:Q', scale=alt.Scale(domain=[20, 90])),
    y=alt.Y('Mortality:Q', scale=alt.Scale(domain=[0, 40])),
    color='Group',
    tooltip=['Country Code']
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    dem.loc[dem.Year == 2019].replace(0, np.nan)
).mark_circle(size=70).encode(
    x=alt.X('Life Expectancy:Q', scale=alt.Scale(domain=[20, 90])),
    y=alt.Y('Mortality:Q', scale=alt.Scale(domain=[0, 40])),
    color='Group',
    tooltip=['Country Code']
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    dem.loc[dem.Year == 2010].replace(0, np.nan)
).mark_circle(size=70).encode(
    x=alt.X('Life Expectancy:Q', scale=alt.Scale(domain=[40, 90])),
    y=alt.Y('Mortality:Q', scale=alt.Scale(domain=[0, 25])),
    color='Group',
    tooltip=['Country Code']
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    dem.loc[
        (dem.Year==2020)&(dem['Country Code'].isin(iso_codes))
    ]
).mark_bar(size=10).encode(
    x='Life Expectancy',
    y=alt.Y('Country Code', sort='-x'),
    color='Group'
).properties(
    height=300
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    dem.loc[
        (dem.Year==2020)&(dem['Country Code'].isin(iso_codes))
    ]
).mark_bar(size=10).encode(
    x='Mortality',
    y=alt.Y('Country Code', sort='-x'),
    color='Group'
).properties(
    height=300
)
# Out:
# alt.Chart(...)

# %%
df_le_mort = dem.loc[
    dem.Year.isin([1991, 2020]) & dem['Country Code'].isin(iso_codes)
].copy()

df_le_mort.loc[
    df_le_mort['Country Code'].isin(['LTU', 'EST', 'LVA']),
    'Group'
] = 'FSU-B'

# Add Pct Change and Labels
pct_change_le = df_le_mort.loc[:, ['Country Code', 'Year', 'Life Expectancy']].groupby('Country Code').apply(
    lambda tx: tx.sort_values(by='Year').loc[:, ['Life Expectancy']].pct_change().iloc[1] * 100
).rename(columns = {'Life Expectancy': 'Pct Change LE'})

pct_change_mort = df_le_mort.loc[:, ['Country Code', 'Year', 'Mortality']].groupby('Country Code').apply(
    lambda tx: tx.sort_values(by='Year').loc[:, ['Mortality']].pct_change().iloc[1] * 100
).rename(columns = {'Mortality': 'Pct Change MORT'})

df_le_mort = df_le_mort.merge(pct_change_le, on = 'Country Code')
df_le_mort = df_le_mort.merge(pct_change_mort, on = 'Country Code')

# %%
alt.Chart(
    df_le_mort.loc[df_le_mort.Year==2020]
).mark_bar(size=10).encode(
    x='Pct Change LE',
    y=alt.Y('Country Code', sort='-x'),
    color='Group'
).properties(
    height=300
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    df_le_mort.loc[df_le_mort.Year==2020]
).mark_bar(size=10).encode(
    x='Pct Change MORT',
    y=alt.Y('Country Code', sort='-x'),
    color='Group'
).properties(
    height=300
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### LIFE EXPECTANCY - TIME SERIES

# %%
le_ts_df = wb.data.DataFrame('SP.DYN.LE00.IN', iso_codes, time=range(1991, 2021), labels=True, skipAggs=True)

# %%
le_ts = le_ts_df.reset_index().rename(columns={'index': 'Country Code', 'Country': 'Country Name'})
le_ts = pd.wide_to_long(le_ts, 'YR', i='Country Code', j='Year').reset_index().rename(columns={'YR': 'Value'})
le_ts = le_ts.merge(countries_df.drop(['independence', 'Country Name'], axis=1), how='left', on='Country Code')

le_ts.loc[le_ts['Country Code'].isin(['LTU', 'LVA', 'EST']), 'Group'] = 'FSU-B'

# %%
alt.Chart(le_ts).mark_line().encode(
    x=alt.X('Year:Q', axis=alt.Axis(tickCount=5, grid=False)),
    y=alt.Y('Value', scale=alt.Scale(domain=[55, 85], nice=False)),
    detail='Country Name',
    color=alt.Color('Group', scale=alt.Scale(domain=['FSU', 'FSU-B', 'FWT'], range=['#800000', '#D3543F', '#FFB495']))
).properties(
    width=250,
    height=250
).facet(
    column='Group:N'
)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# #### SAVE DATA FOR APP

# %%
app_df = le_ts.copy()

app_df.loc[:, 'Indicator Code'] = 'LE_TS'

app_df = app_df.rename(columns = {
    'Country Name': 'countryName',
    'Country Code': 'countryCode',
    'Indicator Code': 'indicatorCode',
    'Group': 'group',
    'Region': 'region',
    'Year': 'year',
    'Value': 'value',
})

# %%
app_df
# Out:
#     countryCode  year         countryName      value          region  group  \
# 0           ROU  1991             Romania  69.784390  Eastern Europe    FWT
# 1           POL  1991              Poland  70.587805  Eastern Europe    FWT
# 2           HUN  1991             Hungary  69.377073  Eastern Europe    FWT
# 3           CZE  1991      Czech Republic  71.898293  Eastern Europe    FWT
# 4           SVK  1991     Slovak Republic  70.882927  Eastern Europe    FWT
# ..          ...   ...                 ...        ...             ...    ...
# 625         LVA  2020              Latvia  75.387805   Baltic states  FSU-B
# 626         LTU  2020           Lithuania  74.929268   Baltic states  FSU-B
# 627         BLR  2020             Belarus  74.226829  Eastern Europe    FSU
# 628         UKR  2020             Ukraine  71.185122  Eastern Europe    FSU
# 629         RUS  2020  Russian Federation  71.338780  Eastern Europe    FSU
#
#     indicatorCode
# 0           LE_TS
# 1           LE_TS
# 2           LE_TS
# 3           LE_TS
# 4           LE_TS
# ..            ...
# 625         LE_TS
# 626         LE_TS
# 627         LE_TS
# 628         LE_TS
# 629         LE_TS
#
# [630 rows x 7 columns]

# %%
app_df.to_json('data/app/LETS.json', orient='records')

# %% [markdown]
# #### HUMAN DEVELOPMENT INDEX

# %%
hdi_gm = pd.read_csv(
    'data/hdi_human_development_index.csv',
    sep=','
)

# %%
def get_iso(name):
    try:
        iso = pycountry.countries.search_fuzzy(name)[0].alpha_3
    except LookupError as e:
        iso = None
        
    return iso

# %%
hdi_gm.loc[:, 'Country Code'] = hdi_gm.country.apply(get_iso)

# %%
hdi_gm = hdi_gm.merge(countries_df.loc[:, ['Group', 'Country Code', 'Region']], on = 'Country Code', how ='right')

# %%
hdi_gm
# Out:
#             country   1990   1991   1992   1993   1994   1995   1996   1997  \
# 0           Armenia  0.654  0.648  0.618  0.617  0.621  0.627  0.634  0.645
# 1        Azerbaijan    NaN    NaN    NaN    NaN    NaN  0.604  0.605  0.610
# 2          Bulgaria  0.708  0.705  0.705  0.704  0.705  0.710  0.718  0.713
# 3           Belarus    NaN    NaN    NaN    NaN    NaN  0.660  0.664  0.670
# 4    Czech Republic  0.738  0.733  0.736  0.743  0.752  0.761  0.776  0.782
# 5           Estonia  0.735  0.730  0.722  0.715  0.720  0.729  0.740  0.754
# 6           Georgia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7           Hungary  0.708  0.706  0.711  0.724  0.737  0.746  0.750  0.751
# 8        Kazakhstan  0.690  0.684  0.682  0.675  0.667  0.664  0.666  0.669
# 9   Kyrgyz Republic  0.640  0.634  0.625  0.612  0.595  0.589  0.594  0.601
# 10        Lithuania  0.738  0.734  0.719  0.708  0.704  0.710  0.719  0.731
# 11           Latvia  0.711  0.706  0.685  0.674  0.675  0.680  0.687  0.698
# 12          Moldova  0.690  0.680  0.661  0.660  0.640  0.638  0.634  0.637
# 13           Poland  0.718  0.716  0.719  0.730  0.739  0.745  0.753  0.764
# 14          Romania  0.708  0.694  0.686  0.686  0.688  0.694  0.702  0.703
# 15           Russia  0.735  0.731  0.720  0.712  0.703  0.702  0.703  0.705
# 16  Slovak Republic  0.741  0.736  0.735  0.738  0.745  0.752  0.756  0.758
# 17       Tajikistan  0.617  0.612  0.592  0.575  0.556  0.549  0.535  0.540
# 18     Turkmenistan    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19          Ukraine  0.725  0.721  0.713  0.703  0.690  0.686  0.684  0.686
# 20       Uzbekistan    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#      1998  ...   2013   2014   2015   2016   2017   2018   2019  Country Code  \
# 0   0.657  ...  0.762  0.764  0.768  0.766  0.769  0.771  0.776           ARM
# 1   0.619  ...  0.735  0.740  0.744  0.751  0.754  0.754  0.756           AZE
# 2   0.718  ...  0.801  0.806  0.809  0.811  0.811  0.813  0.816           BGR
# 3   0.674  ...  0.811  0.814  0.814  0.815  0.819  0.823  0.823           BLR
# 4   0.783  ...  0.882  0.888  0.891  0.893  0.896  0.898  0.900           CZE
# 5   0.766  ...  0.869  0.871  0.877  0.881  0.885  0.889  0.892           EST
# 6     NaN  ...  0.775  0.783  0.790  0.792  0.799  0.805  0.812           GEO
# 7   0.758  ...  0.839  0.838  0.842  0.844  0.846  0.850  0.854           HUN
# 8   0.672  ...  0.791  0.798  0.806  0.808  0.815  0.819  0.825           KAZ
# 9   0.606  ...  0.680  0.686  0.690  0.691  0.694  0.696  0.697           KGZ
# 10  0.743  ...  0.847  0.859  0.862  0.867  0.873  0.876  0.882           LTU
# 11  0.711  ...  0.839  0.845  0.849  0.854  0.859  0.863  0.866           LVA
# 12  0.637  ...  0.735  0.737  0.736  0.738  0.743  0.746  0.750           MDA
# 13  0.774  ...  0.856  0.858  0.863  0.869  0.873  0.877  0.880           POL
# 14  0.705  ...  0.808  0.811  0.815  0.820  0.821  0.823  0.828           ROU
# 15  0.705  ...  0.802  0.807  0.809  0.815  0.820  0.823  0.824           RUS
# 16  0.764  ...  0.845  0.847  0.850  0.853  0.855  0.858  0.860           SVK
# 17  0.544  ...  0.653  0.652  0.652  0.653  0.657  0.661  0.668           TJK
# 18    NaN  ...  0.685  0.689  0.694  0.699  0.701  0.710  0.715           TKM
# 19  0.688  ...  0.767  0.771  0.765  0.768  0.771  0.774  0.779           UKR
# 20    NaN  ...  0.692  0.696  0.701  0.705  0.713  0.717  0.720           UZB
#
#     Group          Region
# 0     FSU  South Caucasus
# 1     FSU  South Caucasus
# 2     FWT  Eastern Europe
# 3     FSU  Eastern Europe
# 4     FWT  Eastern Europe
# 5     FSU   Baltic states
# 6     FSU  South Caucasus
# 7     FWT  Eastern Europe
# 8     FSU    Central Asia
# 9     FSU    Central Asia
# 10    FSU   Baltic states
# 11    FSU   Baltic states
# 12    FSU  Eastern Europe
# 13    FWT  Eastern Europe
# 14    FWT  Eastern Europe
# 15    FSU  Eastern Europe
# 16    FWT  Eastern Europe
# 17    FSU    Central Asia
# 18    FSU    Central Asia
# 19    FSU  Eastern Europe
# 20    FSU    Central Asia
#
# [21 rows x 34 columns]

# %%
hdi_gm.loc[
    hdi_gm.country.isin(['Georgia', 'Turkmenistan', 'Uzbekistan'])
].T
# Out:
#                           6             18            20
# country              Georgia  Turkmenistan    Uzbekistan
# 1990                     NaN           NaN           NaN
# 1991                     NaN           NaN           NaN
# 1992                     NaN           NaN           NaN
# 1993                     NaN           NaN           NaN
# 1994                     NaN           NaN           NaN
# 1995                     NaN           NaN           NaN
# 1996                     NaN           NaN           NaN
# 1997                     NaN           NaN           NaN
# 1998                     NaN           NaN           NaN
# 1999                     NaN           NaN           NaN
# 2000                    0.69           NaN         0.599
# 2001                   0.694           NaN         0.607
# 2002                   0.699           NaN         0.614
# 2003                   0.708           NaN         0.619
# 2004                   0.715           NaN         0.626
# 2005                   0.725           NaN         0.633
# 2006                   0.731           NaN         0.637
# 2007                   0.743           NaN         0.649
# 2008                   0.742           NaN         0.653
# 2009                   0.746           NaN          0.66
# 2010                   0.751         0.666         0.669
# 2011                   0.757         0.673         0.676
# 2012                   0.767         0.679         0.685
# 2013                   0.775         0.685         0.692
# 2014                   0.783         0.689         0.696
# 2015                    0.79         0.694         0.701
# 2016                   0.792         0.699         0.705
# 2017                   0.799         0.701         0.713
# 2018                   0.805          0.71         0.717
# 2019                   0.812         0.715          0.72
# Country Code             GEO           TKM           UZB
# Group                    FSU           FSU           FSU
# Region        South Caucasus  Central Asia  Central Asia

# %% [markdown]
# ### AUGMENTED HUMAN DEVELOPMENT INDEX

# %%
ahdi = pd.read_csv(
    'data/AHDI.csv',
    sep=',',
    usecols = ['country', '1990', '1995', '2000', '2005', '2010', '2015']
)

ahdi.loc[:, 'Country Code'] = ahdi.country.apply(get_iso)

ahdi = ahdi.merge(countries_df.loc[:, ['Group', 'Country Code', 'Region']], on = 'Country Code', how ='right')

# %%
ahdi
# Out:
#        country   1990   1995   2000   2005   2010   2015 Country Code Group  \
# 0      Belarus  0.432  0.419  0.317  0.320  0.348  0.380          BLR   FSU
# 1     Bulgaria  0.412  0.490  0.512  0.544  0.555  0.551          BGR   FWT
# 2      Estonia  0.483  0.537  0.593  0.625  0.648  0.709          EST   FSU
# 3      Hungary  0.469  0.520  0.544  0.575  0.567  0.574          HUN   FWT
# 4       Latvia  0.473  0.499  0.528  0.561  0.573  0.623          LVA   FSU
# 5    Lithuania  0.526  0.508  0.544  0.567  0.604  0.660          LTU   FSU
# 6      Moldova  0.395  0.395  0.408  0.405  0.449  0.510          MDA   FSU
# 7       Poland  0.409  0.492  0.525  0.554  0.582  0.661          POL   FWT
# 8      Romania  0.324  0.417  0.433  0.467  0.498  0.538          ROU   FWT
# 9       Russia  0.316  0.377  0.358  0.352  0.385  0.373          RUS   FSU
# 10  Slovak Rep  0.428  0.503  0.565  0.590  0.617  0.662          SVK   FWT
# 11     Ukraine  0.380  0.402  0.377  0.415  0.439  0.399          UKR   FSU
# 12          UK  0.656  0.682  0.729  0.757  0.788  0.779          UKR   FSU
# 13     Armenia  0.429  0.393  0.393  0.394  0.421  0.455          ARM   FSU
# 14  Azerbaijan  0.287  0.275  0.277  0.278  0.316  0.297          AZE   FSU
# 15     Georgia  0.408  0.401  0.424  0.437  0.449  0.502          GEO   FSU
# 16  Kazakhstan  0.343  0.331  0.335  0.342  0.361  0.378          KAZ   FSU
# 17  Kyrgyzstan  0.312  0.309  0.310  0.322  0.348  0.438          KGZ   FSU
# 18  Tajikistan  0.296  0.218  0.246  0.253  0.255  0.256          TJK   FSU
# 19  Uzbekistan  0.287  0.238  0.224  0.231  0.238  0.276          UZB   FSU
# 20         NaN    NaN    NaN    NaN    NaN    NaN    NaN          CZE   FWT
# 21         NaN    NaN    NaN    NaN    NaN    NaN    NaN          TKM   FSU
#
#             Region
# 0   Eastern Europe
# 1   Eastern Europe
# 2    Baltic states
# 3   Eastern Europe
# 4    Baltic states
# 5    Baltic states
# 6   Eastern Europe
# 7   Eastern Europe
# 8   Eastern Europe
# 9   Eastern Europe
# 10  Eastern Europe
# 11  Eastern Europe
# 12  Eastern Europe
# 13  South Caucasus
# 14  South Caucasus
# 15  South Caucasus
# 16    Central Asia
# 17    Central Asia
# 18    Central Asia
# 19    Central Asia
# 20  Eastern Europe
# 21    Central Asia

# %% [markdown]
# ### NOT ONLY GDP - UNEMPLOYMENT - WORLD BANK ILO ESTIMATE

# %%
# Unemployment, total (% of total labor force) (modeled ILO estimate)
uem_rate = pd.read_csv(
    'data/API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_3629004.csv',
    sep=',',
    skiprows=4,
    usecols = use_cols
)

uem_rate = uem_rate.loc[
    uem_rate['Country Code'].isin(iso_codes + ['EUU', 'ECS', 'ECA'])
]

# %%
uem_rate.head()
# Out:
#       Country Name Country Code  Indicator Code  1990   1991  1992   1993  \
# 10         Armenia          ARM  SL.UEM.TOTL.ZS   NaN   1.60   1.8   5.30
# 15      Azerbaijan          AZE  SL.UEM.TOTL.ZS   NaN   0.90   1.8   4.50
# 21        Bulgaria          BGR  SL.UEM.TOTL.ZS   NaN  11.10  15.3  16.40
# 25         Belarus          BLR  SL.UEM.TOTL.ZS   NaN   0.60   3.1   8.50
# 54  Czech Republic          CZE  SL.UEM.TOTL.ZS   NaN   2.27   2.6   4.32
#
#     1994       1995   1996  ...       2011       2012    2013    2014   2015  \
# 10   6.6   6.700000   9.30  ...  18.440001  17.299999  16.180  17.500  18.26
# 15   6.3   7.200000   8.10  ...   5.420000   5.190000   4.970   4.910   4.96
# 21  12.8  11.100000  12.50  ...  11.260000  12.270000  12.940  11.420   9.14
# 25  12.8  17.700001  24.40  ...   6.166000   6.051000   6.006   5.994   5.84
# 54   4.3   4.020000   3.89  ...   6.710000   6.980000   6.950   6.110   5.05
#
#          2016       2017       2018       2019       2020
# 10  17.620001  17.700001  18.969999  18.299999  21.205999
# 15   5.000000   5.000000   4.900000   4.850000   6.463000
# 21   7.570000   6.160000   5.210000   4.230000   5.120000
# 25   5.840000   5.650000   4.760000   4.160000   4.768000
# 54   3.950000   2.890000   2.240000   2.010000   2.550000
#
# [5 rows x 34 columns]

# %%
uem_rate = uem_rate.melt(
    id_vars = ['Country Name', 'Country Code', 'Indicator Code'],
    value_name = 'Value',
    var_name = 'Year'
)

# %%
uem_rate.loc[
    uem_rate.Value.isnull()
]
# Out:
#                                      Country Name Country Code  \
# 0                                         Armenia          ARM
# 1                                      Azerbaijan          AZE
# 2                                        Bulgaria          BGR
# 3                                         Belarus          BLR
# 4                                  Czech Republic          CZE
# 5   Europe & Central Asia (excluding high income)          ECA
# 6                           Europe & Central Asia          ECS
# 7                                         Estonia          EST
# 8                                  European Union          EUU
# 9                                         Georgia          GEO
# 10                                        Hungary          HUN
# 11                                     Kazakhstan          KAZ
# 12                                Kyrgyz Republic          KGZ
# 13                                      Lithuania          LTU
# 14                                         Latvia          LVA
# 15                                        Moldova          MDA
# 16                                         Poland          POL
# 17                                        Romania          ROU
# 18                             Russian Federation          RUS
# 19                                Slovak Republic          SVK
# 20                                     Tajikistan          TJK
# 21                                   Turkmenistan          TKM
# 22                                        Ukraine          UKR
# 23                                     Uzbekistan          UZB
#
#     Indicator Code  Year  Value
# 0   SL.UEM.TOTL.ZS  1990    NaN
# 1   SL.UEM.TOTL.ZS  1990    NaN
# 2   SL.UEM.TOTL.ZS  1990    NaN
# 3   SL.UEM.TOTL.ZS  1990    NaN
# 4   SL.UEM.TOTL.ZS  1990    NaN
# 5   SL.UEM.TOTL.ZS  1990    NaN
# 6   SL.UEM.TOTL.ZS  1990    NaN
# 7   SL.UEM.TOTL.ZS  1990    NaN
# 8   SL.UEM.TOTL.ZS  1990    NaN
# 9   SL.UEM.TOTL.ZS  1990    NaN
# 10  SL.UEM.TOTL.ZS  1990    NaN
# 11  SL.UEM.TOTL.ZS  1990    NaN
# 12  SL.UEM.TOTL.ZS  1990    NaN
# 13  SL.UEM.TOTL.ZS  1990    NaN
# 14  SL.UEM.TOTL.ZS  1990    NaN
# 15  SL.UEM.TOTL.ZS  1990    NaN
# 16  SL.UEM.TOTL.ZS  1990    NaN
# 17  SL.UEM.TOTL.ZS  1990    NaN
# 18  SL.UEM.TOTL.ZS  1990    NaN
# 19  SL.UEM.TOTL.ZS  1990    NaN
# 20  SL.UEM.TOTL.ZS  1990    NaN
# 21  SL.UEM.TOTL.ZS  1990    NaN
# 22  SL.UEM.TOTL.ZS  1990    NaN
# 23  SL.UEM.TOTL.ZS  1990    NaN

# %% [markdown]
# ### Life expectancy at birth, total (years) - World Bank

# %% [markdown]
# https://data.worldbank.org/indicator/SP.DYN.LE00.IN

# %%
life_exp = pd.read_csv(
    'data/API_SP.DYN.LE00.IN_DS2_en_csv_v2_3630764.csv',
    sep=',',
    skiprows=4,
    usecols = use_cols
)

life_exp = life_exp.loc[
    life_exp['Country Code'].isin(iso_codes + ['EUU', 'ECS', 'ECA'])
]

# %%
life_exp = life_exp.melt(
    id_vars = ['Country Name', 'Country Code', 'Indicator Code'],
    value_name = 'Value',
    var_name = 'Year'
)

# %%
life_exp.loc[
    life_exp.Value.isnull()
]
# Out:
#                                       Country Name Country Code  \
# 720                                        Armenia          ARM
# 721                                     Azerbaijan          AZE
# 722                                       Bulgaria          BGR
# 723                                        Belarus          BLR
# 724                                 Czech Republic          CZE
# 725  Europe & Central Asia (excluding high income)          ECA
# 726                          Europe & Central Asia          ECS
# 727                                        Estonia          EST
# 728                                 European Union          EUU
# 729                                        Georgia          GEO
# 730                                        Hungary          HUN
# 731                                     Kazakhstan          KAZ
# 732                                Kyrgyz Republic          KGZ
# 733                                      Lithuania          LTU
# 734                                         Latvia          LVA
# 735                                        Moldova          MDA
# 736                                         Poland          POL
# 737                                        Romania          ROU
# 738                             Russian Federation          RUS
# 739                                Slovak Republic          SVK
# 740                                     Tajikistan          TJK
# 741                                   Turkmenistan          TKM
# 742                                        Ukraine          UKR
# 743                                     Uzbekistan          UZB
#
#      Indicator Code  Year  Value
# 720  SP.DYN.LE00.IN  2020    NaN
# 721  SP.DYN.LE00.IN  2020    NaN
# 722  SP.DYN.LE00.IN  2020    NaN
# 723  SP.DYN.LE00.IN  2020    NaN
# 724  SP.DYN.LE00.IN  2020    NaN
# 725  SP.DYN.LE00.IN  2020    NaN
# 726  SP.DYN.LE00.IN  2020    NaN
# 727  SP.DYN.LE00.IN  2020    NaN
# 728  SP.DYN.LE00.IN  2020    NaN
# 729  SP.DYN.LE00.IN  2020    NaN
# 730  SP.DYN.LE00.IN  2020    NaN
# 731  SP.DYN.LE00.IN  2020    NaN
# 732  SP.DYN.LE00.IN  2020    NaN
# 733  SP.DYN.LE00.IN  2020    NaN
# 734  SP.DYN.LE00.IN  2020    NaN
# 735  SP.DYN.LE00.IN  2020    NaN
# 736  SP.DYN.LE00.IN  2020    NaN
# 737  SP.DYN.LE00.IN  2020    NaN
# 738  SP.DYN.LE00.IN  2020    NaN
# 739  SP.DYN.LE00.IN  2020    NaN
# 740  SP.DYN.LE00.IN  2020    NaN
# 741  SP.DYN.LE00.IN  2020    NaN
# 742  SP.DYN.LE00.IN  2020    NaN
# 743  SP.DYN.LE00.IN  2020    NaN

# %% [markdown]
# ### High-technology exports (% of manufactured exports) - GP

# %% [markdown]
# ### Current health expenditure per capita, PPP (current international $)

# %%
# https://data.worldbank.org/indicator/SH.XPD.CHEX.PP.CD

# %% [markdown]
# ### Physicians (per 1,000 people)

# %%
# https://data.worldbank.org/indicator/SH.MED.PHYS.ZS

# %% [markdown]
# ### GOVERNANCE INDICATORS

# %%
gov_ind = pd.read_csv('data/governance_indicators_data.csv')

# %%
gov_ind.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name       Series Code  \
# 0                    Control of Corruption: Estimate            CC.EST
# 1           Control of Corruption: Number of Sources         CC.NO.SRC
# 2             Control of Corruption: Percentile Rank        CC.PER.RNK
# 3  Control of Corruption: Percentile Rank, Lower ...  CC.PER.RNK.LOWER
# 4  Control of Corruption: Percentile Rank, Upper ...  CC.PER.RNK.UPPER
#
#   1996 [YR1996] 1998 [YR1998] 2000 [YR2000] 2002 [YR2002] 2003 [YR2003]  \
# 0     -1.291705     -1.180848      -1.29538     -1.263366     -1.351042
# 1             2             2             2             2             3
# 2      4.301075      9.793815      5.076142      5.050505      5.050505
# 3             0             0             0             0             0
# 4      27.41936       31.4433      29.44162      31.81818      18.18182
#
#   2004 [YR2004]  ... 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 0     -1.345281  ...     -1.579174     -1.419741      -1.43651     -1.354829
# 1             5  ...             9            10            11            11
# 2      5.853659  ...     0.9478673      2.369668      1.895735      5.288462
# 3             0  ...             0             0             0     0.4807692
# 4      14.14634  ...      5.687204      11.84834      9.952606          12.5
#
#   2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# 0     -1.342216     -1.526172     -1.515626     -1.487624     -1.400733
# 1            11            10            10            10            10
# 2          6.25      3.365385      3.846154      4.807693      6.730769
# 3      1.442308             0             0             0      1.923077
# 4          12.5      9.615385      9.615385      10.09615      11.53846
#
#   2020 [YR2020]
# 0     -1.475405
# 1             9
# 2      5.288462
# 3             0
# 4      11.05769
#
# [5 rows x 26 columns]

# %%
gov_ind = gov_ind.loc[
    gov_ind['Country Code'].isin(iso_codes)
]

# %%
gov_ind['Country Code'].value_counts()
# Out:
# KAZ    36
# MDA    36
# CZE    36
# ARM    36
# POL    36
# SVK    36
# RUS    36
# TKM    36
# GEO    36
# EST    36
# UKR    36
# LVA    36
# BGR    36
# UZB    36
# BLR    36
# ROU    36
# TJK    36
# LTU    36
# HUN    36
# KGZ    36
# AZE    36
# Name: Country Code, dtype: int64

# %%
gov_ind['Series Name'].value_counts().sort_index()
# Out:
# Control of Corruption: Estimate                                                                                   21
# Control of Corruption: Number of Sources                                                                          21
# Control of Corruption: Percentile Rank                                                                            21
# Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval                                    21
# Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval                                    21
# Control of Corruption: Standard Error                                                                             21
# Government Effectiveness: Estimate                                                                                21
# Government Effectiveness: Number of Sources                                                                       21
# Government Effectiveness: Percentile Rank                                                                         21
# Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval                                 21
# Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval                                 21
# Government Effectiveness: Standard Error                                                                          21
# Political Stability and Absence of Violence/Terrorism: Estimate                                                   21
# Political Stability and Absence of Violence/Terrorism: Number of Sources                                          21
# Political Stability and Absence of Violence/Terrorism: Percentile Rank                                            21
# Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval    21
# Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval    21
# Political Stability and Absence of Violence/Terrorism: Standard Error                                             21
# Regulatory Quality: Estimate                                                                                      21
# Regulatory Quality: Number of Sources                                                                             21
# Regulatory Quality: Percentile Rank                                                                               21
# Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval                                       21
# Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval                                       21
# Regulatory Quality: Standard Error                                                                                21
# Rule of Law: Estimate                                                                                             21
# Rule of Law: Number of Sources                                                                                    21
# Rule of Law: Percentile Rank                                                                                      21
# Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval                                              21
# Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval                                              21
# Rule of Law: Standard Error                                                                                       21
# Voice and Accountability: Estimate                                                                                21
# Voice and Accountability: Number of Sources                                                                       21
# Voice and Accountability: Percentile Rank                                                                         21
# Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval                                 21
# Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval                                 21
# Voice and Accountability: Standard Error                                                                          21
# Name: Series Name, dtype: int64

# %% [markdown]
# ### HAPPINESS SCORE

# %%
whr_index = pd.read_csv('data/WHR/whr-index-2019-2021.csv')

# %%
whr_index.head()
# Out:
#        Country  Happiness score  Year
# 0      Finland            7.769  2019
# 1      Denmark            7.600  2019
# 2       Norway            7.554  2019
# 3      Iceland            7.494  2019
# 4  Netherlands            7.488  2019
